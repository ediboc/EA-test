# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from xgboost.sklearn import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')
tfidf_model = TfidfVectorizer(
        max_features=1000,
        analyzer='word',
        ngram_range=(1, 2)
        )
MAINDIR = "./gdrive/My Drive/NLP_Movie/"
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
#Load data
df = pd.read_csv(MAINDIR + 'data_preproces.csv')

# %%
df.head()
# Out:
#           docuName  ... category_id
# 0  cv000_29590.txt  ...           1
# 1  cv003_11664.txt  ...           1
# 2  cv004_11636.txt  ...           1
# 3  cv008_29435.txt  ...           1
# 4  cv001_18431.txt  ...           1
#
# [5 rows x 5 columns]

# %%
#Select train and test data
X_train, X_test, y_train, y_test = train_test_split(df.text.values, df.category_id.values, test_size=0.05, random_state=38)

# %%
#tfidf model
tfidf_model = tfidf_model.fit(X_train)

# %%
joblib.dump(tfidf_model, MAINDIR + 'tfidf.pkl')
# Out:
# ['./gdrive/My Drive/NLP_Movie/tfidf.pkl']

# %%
# transform text to numeric vector
X_train_vec = tfidf_model.transform(X_train)
X_train_vec = X_train_vec.toarray()
X_test_vec = tfidf_model.transform(X_test)
X_test_vec = X_test_vec.toarray()

# %% [markdown]
# # Models

# %% [markdown]
# ## Machine learning models

# %%
#To apply RandomizedSearchCV and save machine learning models
def randomize_function(model, x, y,paramDic, classif_folder=None, classifier ='classifier', n_jobs = -1, cv = 3, n_iter =10):
    
    if classif_folder== None:
      classif_folder = ''
    
    #In case of n_iter is greater than the possible combinations
    vals = 1
    for l in paramDic.values(): vals = vals*len(l)
    nIter = min(vals,n_iter)

    clf = RandomizedSearchCV(estimator=model, param_distributions=paramDic,
                             n_jobs=n_jobs, cv=cv, n_iter=nIter, return_train_score=True)

    clf.fit(x, y)
    
    
    with open(MAINDIR + classif_folder+'/'+classifier+'_best_params.txt', "w") as text_file:
      print(clf.best_params_, file=text_file)
     
    
    
    clf2 = model
    print(classifier, clf.best_params_)
    clf2.set_params(**clf.best_params_)
    clf2.fit(x, y)
    
    joblib.dump(clf2, MAINDIR + classif_folder + '/'+ classifier + '.pkl')
    
    acc_train = clf2.score(x, y)
    
    return clf2, acc_train

# %% [markdown]
# ### Run Machine Learning Models

# %%
paramLR = {'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 'C':[1,.01,.01,.001],'class_weight':['balanced',None]}
paramSVC = {'C': np.arange(1,1000,50), 'kernel': ['linear', 'poly', 'rbf'],'gamma': np.arange(0.5,100,50)}
paramXGB = {'max_depth':[3,5,7], 'learning_rate':[0.1,0.05],'n_estimators':np.arange(90,160,10),'booster':['gbtree', 'gblinear', 'dart']}

models = [('LogisticRegression', LogisticRegression(), paramLR),
          ('SVC',SVC(), paramSVC),
          ('XGBClassifier', XGBClassifier(), paramXGB)
         ]

metrics = []
for name, model, param in models:
  clf, acc_train = randomize_function(model, X_train_vec, y_train, param, classifier=name)
  acc_test = clf.score(X_test_vec, y_test)
  metrics.append((name, acc_train, acc_test))
# Out:
# LogisticRegression {'solver': 'sag', 'class_weight': None, 'C': 1}
# SVC {'kernel': 'rbf', 'gamma': 0.5, 'C': 1}
# XGBClassifier {'n_estimators': 90, 'max_depth': 5, 'learning_rate': 0.1, 'booster': 'gbtree'}

# %%
# results: (model, train accuracy, test accuracy)
metrics
# Out:
# [('LogisticRegression', 0.8642105263157894, 0.77),
#  ('SVC', 0.891578947368421, 0.77),
#  ('XGBClassifier', 0.998421052631579, 0.77)]

# %% [markdown]
# ## Neural Networw

# %%
import keras
#from keras import backend as k
from keras.models import Sequential, load_model
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
#from keras.metrics import categorical_crossentropy
from keras import callbacks
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
#hot encoding
y_trainNN = pd.get_dummies(y_train).values

# %%
#Build NN
model = Sequential([
    Dense(512,input_shape=(X_train_vec.shape[1],),activation='relu'),
    Dense(256,activation='relu'),
    Dense(64,activation='relu'),
    Dropout(0.25),
    Dense(y_trainNN.shape[1], activation = 'softmax')             
])

# %%
model.compile(Adam(lr=.00001), loss='categorical_crossentropy', metrics=['accuracy']) #.0001

# %%
#Define early stoping and save best model 
patience = 10
callbacks_list = [ callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=1),]
  
callbacks_list.append(callbacks.ModelCheckpoint(MAINDIR +'NN_model2.h5',
                                          monitor='val_loss', verbose=1,
                                          save_best_only=True, mode='min'))

# %%
#train model
model.fit(X_train_vec, y_trainNN, batch_size=100, epochs=300, verbose = 2, callbacks=callbacks_list, 
          validation_split=.05)
# Out:
# Train on 1805 samples, validate on 95 samples
# Epoch 1/300
#  - 1s - loss: 0.6926 - acc: 0.5330 - val_loss: 0.6928 - val_acc: 0.4316
#
# Epoch 00001: val_loss improved from inf to 0.69282, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 2/300
#  - 0s - loss: 0.6923 - acc: 0.5407 - val_loss: 0.6924 - val_acc: 0.4737
#
# Epoch 00002: val_loss improved from 0.69282 to 0.69242, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 3/300
#  - 0s - loss: 0.6919 - acc: 0.5540 - val_loss: 0.6921 - val_acc: 0.4842
#
# Epoch 00003: val_loss improved from 0.69242 to 0.69212, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 4/300
#  - 0s - loss: 0.6915 - acc: 0.5518 - val_loss: 0.6922 - val_acc: 0.4737
#
# Epoch 00004: val_loss did not improve from 0.69212
# Epoch 5/300
#  - 0s - loss: 0.6906 - acc: 0.5850 - val_loss: 0.6920 - val_acc: 0.4842
#
# Epoch 00005: val_loss improved from 0.69212 to 0.69204, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 6/300
#  - 0s - loss: 0.6905 - acc: 0.5806 - val_loss: 0.6917 - val_acc: 0.4947
#
# Epoch 00006: val_loss improved from 0.69204 to 0.69168, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 7/300
#  - 0s - loss: 0.6901 - acc: 0.5867 - val_loss: 0.6915 - val_acc: 0.5053
#
# Epoch 00007: val_loss improved from 0.69168 to 0.69147, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 8/300
#  - 0s - loss: 0.6895 - acc: 0.6050 - val_loss: 0.6914 - val_acc: 0.4947
#
# Epoch 00008: val_loss improved from 0.69147 to 0.69136, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 9/300
#  - 0s - loss: 0.6889 - acc: 0.6105 - val_loss: 0.6910 - val_acc: 0.5263
#
# Epoch 00009: val_loss improved from 0.69136 to 0.69101, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 10/300
#  - 0s - loss: 0.6881 - acc: 0.6066 - val_loss: 0.6911 - val_acc: 0.4947
#
# Epoch 00010: val_loss did not improve from 0.69101
# Epoch 11/300
#  - 0s - loss: 0.6878 - acc: 0.6083 - val_loss: 0.6911 - val_acc: 0.4842
#
# Epoch 00011: val_loss did not improve from 0.69101
# Epoch 12/300
#  - 0s - loss: 0.6871 - acc: 0.6028 - val_loss: 0.6909 - val_acc: 0.4842
#
# Epoch 00012: val_loss improved from 0.69101 to 0.69089, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 13/300
#  - 0s - loss: 0.6867 - acc: 0.6000 - val_loss: 0.6904 - val_acc: 0.5053
#
# Epoch 00013: val_loss improved from 0.69089 to 0.69043, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 14/300
#  - 0s - loss: 0.6859 - acc: 0.6238 - val_loss: 0.6898 - val_acc: 0.5368
#
# Epoch 00014: val_loss improved from 0.69043 to 0.68981, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 15/300
#  - 0s - loss: 0.6852 - acc: 0.6366 - val_loss: 0.6890 - val_acc: 0.5368
#
# Epoch 00015: val_loss improved from 0.68981 to 0.68902, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 16/300
#  - 0s - loss: 0.6848 - acc: 0.6343 - val_loss: 0.6892 - val_acc: 0.5263
#
# Epoch 00016: val_loss did not improve from 0.68902
# Epoch 17/300
#  - 0s - loss: 0.6830 - acc: 0.6332 - val_loss: 0.6886 - val_acc: 0.5263
#
# Epoch 00017: val_loss improved from 0.68902 to 0.68860, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 18/300
#  - 0s - loss: 0.6829 - acc: 0.6305 - val_loss: 0.6876 - val_acc: 0.5368
#
# Epoch 00018: val_loss improved from 0.68860 to 0.68763, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 19/300
#  - 0s - loss: 0.6820 - acc: 0.6476 - val_loss: 0.6864 - val_acc: 0.5368
#
# Epoch 00019: val_loss improved from 0.68763 to 0.68643, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 20/300
#  - 0s - loss: 0.6802 - acc: 0.6632 - val_loss: 0.6857 - val_acc: 0.5368
#
# Epoch 00020: val_loss improved from 0.68643 to 0.68572, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 21/300
#  - 0s - loss: 0.6792 - acc: 0.6665 - val_loss: 0.6844 - val_acc: 0.5579
#
# Epoch 00021: val_loss improved from 0.68572 to 0.68444, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 22/300
#  - 0s - loss: 0.6781 - acc: 0.6803 - val_loss: 0.6829 - val_acc: 0.5895
#
# Epoch 00022: val_loss improved from 0.68444 to 0.68289, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 23/300
#  - 0s - loss: 0.6773 - acc: 0.7053 - val_loss: 0.6810 - val_acc: 0.6316
#
# Epoch 00023: val_loss improved from 0.68289 to 0.68098, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 24/300
#  - 0s - loss: 0.6757 - acc: 0.7163 - val_loss: 0.6798 - val_acc: 0.6316
#
# Epoch 00024: val_loss improved from 0.68098 to 0.67981, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 25/300
#  - 0s - loss: 0.6730 - acc: 0.7208 - val_loss: 0.6793 - val_acc: 0.6000
#
# Epoch 00025: val_loss improved from 0.67981 to 0.67931, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 26/300
#  - 0s - loss: 0.6718 - acc: 0.7036 - val_loss: 0.6792 - val_acc: 0.5895
#
# Epoch 00026: val_loss improved from 0.67931 to 0.67924, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 27/300
#  - 0s - loss: 0.6704 - acc: 0.7125 - val_loss: 0.6779 - val_acc: 0.6105
#
# Epoch 00027: val_loss improved from 0.67924 to 0.67786, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 28/300
#  - 0s - loss: 0.6688 - acc: 0.7058 - val_loss: 0.6757 - val_acc: 0.6421
#
# Epoch 00028: val_loss improved from 0.67786 to 0.67573, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 29/300
#  - 0s - loss: 0.6673 - acc: 0.7280 - val_loss: 0.6734 - val_acc: 0.6526
#
# Epoch 00029: val_loss improved from 0.67573 to 0.67342, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 30/300
#  - 0s - loss: 0.6637 - acc: 0.7507 - val_loss: 0.6713 - val_acc: 0.6632
#
# Epoch 00030: val_loss improved from 0.67342 to 0.67129, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 31/300
#  - 0s - loss: 0.6639 - acc: 0.7407 - val_loss: 0.6699 - val_acc: 0.6632
#
# Epoch 00031: val_loss improved from 0.67129 to 0.66989, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 32/300
#  - 0s - loss: 0.6603 - acc: 0.7546 - val_loss: 0.6696 - val_acc: 0.6421
#
# Epoch 00032: val_loss improved from 0.66989 to 0.66961, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 33/300
#  - 0s - loss: 0.6596 - acc: 0.7407 - val_loss: 0.6670 - val_acc: 0.6526
#
# Epoch 00033: val_loss improved from 0.66961 to 0.66703, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 34/300
#  - 0s - loss: 0.6565 - acc: 0.7607 - val_loss: 0.6645 - val_acc: 0.6842
#
# Epoch 00034: val_loss improved from 0.66703 to 0.66449, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 35/300
#  - 0s - loss: 0.6542 - acc: 0.7651 - val_loss: 0.6616 - val_acc: 0.6842
#
# Epoch 00035: val_loss improved from 0.66449 to 0.66160, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 36/300
#  - 0s - loss: 0.6522 - acc: 0.7690 - val_loss: 0.6596 - val_acc: 0.7053
#
# Epoch 00036: val_loss improved from 0.66160 to 0.65959, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 37/300
#  - 0s - loss: 0.6491 - acc: 0.7828 - val_loss: 0.6547 - val_acc: 0.7579
#
# Epoch 00037: val_loss improved from 0.65959 to 0.65474, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 38/300
#  - 0s - loss: 0.6462 - acc: 0.7784 - val_loss: 0.6538 - val_acc: 0.7474
#
# Epoch 00038: val_loss improved from 0.65474 to 0.65380, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 39/300
#  - 0s - loss: 0.6427 - acc: 0.7967 - val_loss: 0.6508 - val_acc: 0.7474
#
# Epoch 00039: val_loss improved from 0.65380 to 0.65079, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 40/300
#  - 0s - loss: 0.6391 - acc: 0.7911 - val_loss: 0.6500 - val_acc: 0.7263
#
# Epoch 00040: val_loss improved from 0.65079 to 0.65005, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 41/300
#  - 0s - loss: 0.6357 - acc: 0.7983 - val_loss: 0.6463 - val_acc: 0.7368
#
# Epoch 00041: val_loss improved from 0.65005 to 0.64626, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 42/300
#  - 0s - loss: 0.6324 - acc: 0.7983 - val_loss: 0.6443 - val_acc: 0.7263
#
# Epoch 00042: val_loss improved from 0.64626 to 0.64428, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 43/300
#  - 0s - loss: 0.6287 - acc: 0.7939 - val_loss: 0.6419 - val_acc: 0.7263
#
# Epoch 00043: val_loss improved from 0.64428 to 0.64190, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 44/300
#  - 0s - loss: 0.6247 - acc: 0.7994 - val_loss: 0.6394 - val_acc: 0.7158
#
# Epoch 00044: val_loss improved from 0.64190 to 0.63943, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 45/300
#  - 0s - loss: 0.6215 - acc: 0.7911 - val_loss: 0.6370 - val_acc: 0.7158
#
# Epoch 00045: val_loss improved from 0.63943 to 0.63701, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 46/300
#  - 0s - loss: 0.6178 - acc: 0.7956 - val_loss: 0.6349 - val_acc: 0.7158
#
# Epoch 00046: val_loss improved from 0.63701 to 0.63490, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 47/300
#  - 0s - loss: 0.6134 - acc: 0.7939 - val_loss: 0.6312 - val_acc: 0.7158
#
# Epoch 00047: val_loss improved from 0.63490 to 0.63118, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 48/300
#  - 0s - loss: 0.6111 - acc: 0.8039 - val_loss: 0.6267 - val_acc: 0.7579
#
# Epoch 00048: val_loss improved from 0.63118 to 0.62665, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 49/300
#  - 0s - loss: 0.6061 - acc: 0.8194 - val_loss: 0.6228 - val_acc: 0.7684
#
# Epoch 00049: val_loss improved from 0.62665 to 0.62281, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 50/300
#  - 0s - loss: 0.6028 - acc: 0.8089 - val_loss: 0.6200 - val_acc: 0.7684
#
# Epoch 00050: val_loss improved from 0.62281 to 0.61998, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 51/300
#  - 0s - loss: 0.5986 - acc: 0.8116 - val_loss: 0.6177 - val_acc: 0.7474
#
# Epoch 00051: val_loss improved from 0.61998 to 0.61769, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 52/300
#  - 0s - loss: 0.5941 - acc: 0.8089 - val_loss: 0.6132 - val_acc: 0.7684
#
# Epoch 00052: val_loss improved from 0.61769 to 0.61323, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 53/300
#  - 0s - loss: 0.5905 - acc: 0.8166 - val_loss: 0.6063 - val_acc: 0.7579
#
# Epoch 00053: val_loss improved from 0.61323 to 0.60627, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 54/300
#  - 0s - loss: 0.5835 - acc: 0.8255 - val_loss: 0.6051 - val_acc: 0.7895
#
# Epoch 00054: val_loss improved from 0.60627 to 0.60513, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 55/300
#  - 0s - loss: 0.5773 - acc: 0.8233 - val_loss: 0.6031 - val_acc: 0.7684
#
# Epoch 00055: val_loss improved from 0.60513 to 0.60314, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 56/300
#  - 0s - loss: 0.5735 - acc: 0.8266 - val_loss: 0.5972 - val_acc: 0.7684
#
# Epoch 00056: val_loss improved from 0.60314 to 0.59719, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 57/300
#  - 0s - loss: 0.5730 - acc: 0.8166 - val_loss: 0.5955 - val_acc: 0.7789
#
# Epoch 00057: val_loss improved from 0.59719 to 0.59550, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 58/300
#  - 0s - loss: 0.5658 - acc: 0.8338 - val_loss: 0.5888 - val_acc: 0.7789
#
# Epoch 00058: val_loss improved from 0.59550 to 0.58878, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 59/300
#  - 0s - loss: 0.5600 - acc: 0.8266 - val_loss: 0.5894 - val_acc: 0.7684
#
# Epoch 00059: val_loss did not improve from 0.58878
# Epoch 60/300
#  - 0s - loss: 0.5573 - acc: 0.8294 - val_loss: 0.5869 - val_acc: 0.7684
#
# Epoch 00060: val_loss improved from 0.58878 to 0.58690, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 61/300
#  - 0s - loss: 0.5512 - acc: 0.8305 - val_loss: 0.5804 - val_acc: 0.7684
#
# Epoch 00061: val_loss improved from 0.58690 to 0.58036, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 62/300
#  - 0s - loss: 0.5479 - acc: 0.8277 - val_loss: 0.5717 - val_acc: 0.7789
#
# Epoch 00062: val_loss improved from 0.58036 to 0.57171, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 63/300
#  - 0s - loss: 0.5410 - acc: 0.8382 - val_loss: 0.5674 - val_acc: 0.7789
#
# Epoch 00063: val_loss improved from 0.57171 to 0.56739, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 64/300
#  - 0s - loss: 0.5350 - acc: 0.8366 - val_loss: 0.5599 - val_acc: 0.7579
#
# Epoch 00064: val_loss improved from 0.56739 to 0.55989, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 65/300
#  - 0s - loss: 0.5312 - acc: 0.8443 - val_loss: 0.5583 - val_acc: 0.7789
#
# Epoch 00065: val_loss improved from 0.55989 to 0.55832, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 66/300
#  - 0s - loss: 0.5258 - acc: 0.8366 - val_loss: 0.5548 - val_acc: 0.7789
#
# Epoch 00066: val_loss improved from 0.55832 to 0.55481, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 67/300
#  - 0s - loss: 0.5234 - acc: 0.8360 - val_loss: 0.5554 - val_acc: 0.7789
#
# Epoch 00067: val_loss did not improve from 0.55481
# Epoch 68/300
#  - 0s - loss: 0.5155 - acc: 0.8438 - val_loss: 0.5446 - val_acc: 0.7579
#
# Epoch 00068: val_loss improved from 0.55481 to 0.54455, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 69/300
#  - 0s - loss: 0.5118 - acc: 0.8410 - val_loss: 0.5423 - val_acc: 0.7579
#
# Epoch 00069: val_loss improved from 0.54455 to 0.54230, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 70/300
#  - 0s - loss: 0.5083 - acc: 0.8404 - val_loss: 0.5395 - val_acc: 0.7789
#
# Epoch 00070: val_loss improved from 0.54230 to 0.53953, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 71/300
#  - 0s - loss: 0.4996 - acc: 0.8499 - val_loss: 0.5334 - val_acc: 0.7579
#
# Epoch 00071: val_loss improved from 0.53953 to 0.53342, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 72/300
#  - 0s - loss: 0.4953 - acc: 0.8532 - val_loss: 0.5322 - val_acc: 0.7789
#
# Epoch 00072: val_loss improved from 0.53342 to 0.53223, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 73/300
#  - 0s - loss: 0.4902 - acc: 0.8537 - val_loss: 0.5242 - val_acc: 0.7684
#
# Epoch 00073: val_loss improved from 0.53223 to 0.52418, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 74/300
#  - 0s - loss: 0.4843 - acc: 0.8576 - val_loss: 0.5224 - val_acc: 0.7579
#
# Epoch 00074: val_loss improved from 0.52418 to 0.52241, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 75/300
#  - 0s - loss: 0.4819 - acc: 0.8526 - val_loss: 0.5200 - val_acc: 0.7684
#
# Epoch 00075: val_loss improved from 0.52241 to 0.52001, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 76/300
#  - 0s - loss: 0.4755 - acc: 0.8571 - val_loss: 0.5173 - val_acc: 0.7684
#
# Epoch 00076: val_loss improved from 0.52001 to 0.51734, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 77/300
#  - 0s - loss: 0.4701 - acc: 0.8521 - val_loss: 0.5163 - val_acc: 0.7789
#
# Epoch 00077: val_loss improved from 0.51734 to 0.51627, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 78/300
#  - 0s - loss: 0.4623 - acc: 0.8582 - val_loss: 0.5077 - val_acc: 0.7789
#
# Epoch 00078: val_loss improved from 0.51627 to 0.50774, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 79/300
#  - 0s - loss: 0.4617 - acc: 0.8593 - val_loss: 0.5037 - val_acc: 0.7789
#
# Epoch 00079: val_loss improved from 0.50774 to 0.50365, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 80/300
#  - 0s - loss: 0.4545 - acc: 0.8643 - val_loss: 0.5008 - val_acc: 0.7789
#
# Epoch 00080: val_loss improved from 0.50365 to 0.50085, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 81/300
#  - 0s - loss: 0.4513 - acc: 0.8582 - val_loss: 0.4947 - val_acc: 0.8000
#
# Epoch 00081: val_loss improved from 0.50085 to 0.49471, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 82/300
#  - 0s - loss: 0.4453 - acc: 0.8626 - val_loss: 0.4936 - val_acc: 0.7789
#
# Epoch 00082: val_loss improved from 0.49471 to 0.49356, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 83/300
#  - 0s - loss: 0.4404 - acc: 0.8620 - val_loss: 0.4946 - val_acc: 0.7684
#
# Epoch 00083: val_loss did not improve from 0.49356
# Epoch 84/300
#  - 0s - loss: 0.4363 - acc: 0.8620 - val_loss: 0.4899 - val_acc: 0.7684
#
# Epoch 00084: val_loss improved from 0.49356 to 0.48989, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 85/300
#  - 0s - loss: 0.4301 - acc: 0.8676 - val_loss: 0.4863 - val_acc: 0.7684
#
# Epoch 00085: val_loss improved from 0.48989 to 0.48631, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 86/300
#  - 0s - loss: 0.4238 - acc: 0.8604 - val_loss: 0.4783 - val_acc: 0.8105
#
# Epoch 00086: val_loss improved from 0.48631 to 0.47828, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 87/300
#  - 0s - loss: 0.4217 - acc: 0.8709 - val_loss: 0.4739 - val_acc: 0.8105
#
# Epoch 00087: val_loss improved from 0.47828 to 0.47389, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 88/300
#  - 0s - loss: 0.4155 - acc: 0.8720 - val_loss: 0.4787 - val_acc: 0.7789
#
# Epoch 00088: val_loss did not improve from 0.47389
# Epoch 89/300
#  - 0s - loss: 0.4097 - acc: 0.8693 - val_loss: 0.4703 - val_acc: 0.8000
#
# Epoch 00089: val_loss improved from 0.47389 to 0.47031, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 90/300
#  - 0s - loss: 0.4072 - acc: 0.8765 - val_loss: 0.4667 - val_acc: 0.8000
#
# Epoch 00090: val_loss improved from 0.47031 to 0.46670, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 91/300
#  - 0s - loss: 0.4042 - acc: 0.8726 - val_loss: 0.4640 - val_acc: 0.8000
#
# Epoch 00091: val_loss improved from 0.46670 to 0.46402, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 92/300
#  - 0s - loss: 0.4005 - acc: 0.8676 - val_loss: 0.4588 - val_acc: 0.8000
#
# Epoch 00092: val_loss improved from 0.46402 to 0.45884, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 93/300
#  - 0s - loss: 0.3895 - acc: 0.8820 - val_loss: 0.4592 - val_acc: 0.8105
#
# Epoch 00093: val_loss did not improve from 0.45884
# Epoch 94/300
#  - 0s - loss: 0.3882 - acc: 0.8765 - val_loss: 0.4547 - val_acc: 0.8105
#
# Epoch 00094: val_loss improved from 0.45884 to 0.45466, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 95/300
#  - 0s - loss: 0.3819 - acc: 0.8820 - val_loss: 0.4535 - val_acc: 0.8105
#
# Epoch 00095: val_loss improved from 0.45466 to 0.45348, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 96/300
#  - 0s - loss: 0.3793 - acc: 0.8798 - val_loss: 0.4526 - val_acc: 0.8000
#
# Epoch 00096: val_loss improved from 0.45348 to 0.45259, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 97/300
#  - 0s - loss: 0.3755 - acc: 0.8837 - val_loss: 0.4470 - val_acc: 0.8105
#
# Epoch 00097: val_loss improved from 0.45259 to 0.44699, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 98/300
#  - 0s - loss: 0.3693 - acc: 0.8792 - val_loss: 0.4431 - val_acc: 0.8105
#
# Epoch 00098: val_loss improved from 0.44699 to 0.44307, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 99/300
#  - 0s - loss: 0.3687 - acc: 0.8781 - val_loss: 0.4383 - val_acc: 0.8105
#
# Epoch 00099: val_loss improved from 0.44307 to 0.43834, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 100/300
#  - 0s - loss: 0.3627 - acc: 0.8842 - val_loss: 0.4388 - val_acc: 0.8105
#
# Epoch 00100: val_loss did not improve from 0.43834
# Epoch 101/300
#  - 0s - loss: 0.3576 - acc: 0.8903 - val_loss: 0.4323 - val_acc: 0.8105
#
# Epoch 00101: val_loss improved from 0.43834 to 0.43231, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 102/300
#  - 0s - loss: 0.3495 - acc: 0.8920 - val_loss: 0.4357 - val_acc: 0.8000
#
# Epoch 00102: val_loss did not improve from 0.43231
# Epoch 103/300
#  - 0s - loss: 0.3479 - acc: 0.8787 - val_loss: 0.4335 - val_acc: 0.8000
#
# Epoch 00103: val_loss did not improve from 0.43231
# Epoch 104/300
#  - 0s - loss: 0.3454 - acc: 0.8864 - val_loss: 0.4225 - val_acc: 0.8105
#
# Epoch 00104: val_loss improved from 0.43231 to 0.42255, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 105/300
#  - 0s - loss: 0.3424 - acc: 0.8925 - val_loss: 0.4244 - val_acc: 0.8105
#
# Epoch 00105: val_loss did not improve from 0.42255
# Epoch 106/300
#  - 0s - loss: 0.3381 - acc: 0.8942 - val_loss: 0.4221 - val_acc: 0.8000
#
# Epoch 00106: val_loss improved from 0.42255 to 0.42211, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 107/300
#  - 0s - loss: 0.3361 - acc: 0.8914 - val_loss: 0.4190 - val_acc: 0.8000
#
# Epoch 00107: val_loss improved from 0.42211 to 0.41900, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 108/300
#  - 0s - loss: 0.3289 - acc: 0.8931 - val_loss: 0.4187 - val_acc: 0.8000
#
# Epoch 00108: val_loss improved from 0.41900 to 0.41865, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 109/300
#  - 0s - loss: 0.3295 - acc: 0.8942 - val_loss: 0.4181 - val_acc: 0.8000
#
# Epoch 00109: val_loss improved from 0.41865 to 0.41807, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 110/300
#  - 0s - loss: 0.3252 - acc: 0.8925 - val_loss: 0.4136 - val_acc: 0.8000
#
# Epoch 00110: val_loss improved from 0.41807 to 0.41363, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 111/300
#  - 0s - loss: 0.3196 - acc: 0.8964 - val_loss: 0.4116 - val_acc: 0.8000
#
# Epoch 00111: val_loss improved from 0.41363 to 0.41159, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 112/300
#  - 0s - loss: 0.3166 - acc: 0.8964 - val_loss: 0.4101 - val_acc: 0.8000
#
# Epoch 00112: val_loss improved from 0.41159 to 0.41010, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 113/300
#  - 0s - loss: 0.3152 - acc: 0.9053 - val_loss: 0.4155 - val_acc: 0.8000
#
# Epoch 00113: val_loss did not improve from 0.41010
# Epoch 114/300
#  - 0s - loss: 0.3098 - acc: 0.8986 - val_loss: 0.4016 - val_acc: 0.8105
#
# Epoch 00114: val_loss improved from 0.41010 to 0.40163, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 115/300
#  - 0s - loss: 0.3110 - acc: 0.9003 - val_loss: 0.3996 - val_acc: 0.8105
#
# Epoch 00115: val_loss improved from 0.40163 to 0.39963, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 116/300
#  - 0s - loss: 0.3031 - acc: 0.9064 - val_loss: 0.4037 - val_acc: 0.7895
#
# Epoch 00116: val_loss did not improve from 0.39963
# Epoch 117/300
#  - 0s - loss: 0.2996 - acc: 0.9058 - val_loss: 0.4008 - val_acc: 0.8000
#
# Epoch 00117: val_loss did not improve from 0.39963
# Epoch 118/300
#  - 0s - loss: 0.2952 - acc: 0.9075 - val_loss: 0.3968 - val_acc: 0.8105
#
# Epoch 00118: val_loss improved from 0.39963 to 0.39677, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 119/300
#  - 0s - loss: 0.2935 - acc: 0.9042 - val_loss: 0.3973 - val_acc: 0.8105
#
# Epoch 00119: val_loss did not improve from 0.39677
# Epoch 120/300
#  - 0s - loss: 0.2925 - acc: 0.9136 - val_loss: 0.3977 - val_acc: 0.8000
#
# Epoch 00120: val_loss did not improve from 0.39677
# Epoch 121/300
#  - 0s - loss: 0.2872 - acc: 0.9086 - val_loss: 0.3916 - val_acc: 0.8105
#
# Epoch 00121: val_loss improved from 0.39677 to 0.39157, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 122/300
#  - 0s - loss: 0.2850 - acc: 0.9169 - val_loss: 0.3921 - val_acc: 0.8105
#
# Epoch 00122: val_loss did not improve from 0.39157
# Epoch 123/300
#  - 0s - loss: 0.2802 - acc: 0.9119 - val_loss: 0.3896 - val_acc: 0.8105
#
# Epoch 00123: val_loss improved from 0.39157 to 0.38963, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 124/300
#  - 0s - loss: 0.2776 - acc: 0.9136 - val_loss: 0.3824 - val_acc: 0.8105
#
# Epoch 00124: val_loss improved from 0.38963 to 0.38238, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 125/300
#  - 0s - loss: 0.2745 - acc: 0.9147 - val_loss: 0.3828 - val_acc: 0.8105
#
# Epoch 00125: val_loss did not improve from 0.38238
# Epoch 126/300
#  - 0s - loss: 0.2714 - acc: 0.9125 - val_loss: 0.3874 - val_acc: 0.8105
#
# Epoch 00126: val_loss did not improve from 0.38238
# Epoch 127/300
#  - 0s - loss: 0.2695 - acc: 0.9147 - val_loss: 0.3815 - val_acc: 0.8105
#
# Epoch 00127: val_loss improved from 0.38238 to 0.38147, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 128/300
#  - 0s - loss: 0.2642 - acc: 0.9213 - val_loss: 0.3802 - val_acc: 0.8105
#
# Epoch 00128: val_loss improved from 0.38147 to 0.38019, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 129/300
#  - 0s - loss: 0.2631 - acc: 0.9169 - val_loss: 0.3808 - val_acc: 0.8105
#
# Epoch 00129: val_loss did not improve from 0.38019
# Epoch 130/300
#  - 0s - loss: 0.2627 - acc: 0.9197 - val_loss: 0.3823 - val_acc: 0.8105
#
# Epoch 00130: val_loss did not improve from 0.38019
# Epoch 131/300
#  - 0s - loss: 0.2585 - acc: 0.9180 - val_loss: 0.3794 - val_acc: 0.8105
#
# Epoch 00131: val_loss improved from 0.38019 to 0.37939, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 132/300
#  - 0s - loss: 0.2587 - acc: 0.9141 - val_loss: 0.3782 - val_acc: 0.8105
#
# Epoch 00132: val_loss improved from 0.37939 to 0.37825, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 133/300
#  - 0s - loss: 0.2564 - acc: 0.9136 - val_loss: 0.3812 - val_acc: 0.8105
#
# Epoch 00133: val_loss did not improve from 0.37825
# Epoch 134/300
#  - 0s - loss: 0.2522 - acc: 0.9197 - val_loss: 0.3823 - val_acc: 0.8105
#
# Epoch 00134: val_loss did not improve from 0.37825
# Epoch 135/300
#  - 0s - loss: 0.2520 - acc: 0.9224 - val_loss: 0.3748 - val_acc: 0.8000
#
# Epoch 00135: val_loss improved from 0.37825 to 0.37479, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 136/300
#  - 0s - loss: 0.2473 - acc: 0.9258 - val_loss: 0.3819 - val_acc: 0.8000
#
# Epoch 00136: val_loss did not improve from 0.37479
# Epoch 137/300
#  - 0s - loss: 0.2447 - acc: 0.9235 - val_loss: 0.3728 - val_acc: 0.8000
#
# Epoch 00137: val_loss improved from 0.37479 to 0.37277, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 138/300
#  - 0s - loss: 0.2454 - acc: 0.9235 - val_loss: 0.3749 - val_acc: 0.8000
#
# Epoch 00138: val_loss did not improve from 0.37277
# Epoch 139/300
#  - 0s - loss: 0.2451 - acc: 0.9202 - val_loss: 0.3757 - val_acc: 0.8000
#
# Epoch 00139: val_loss did not improve from 0.37277
# Epoch 140/300
#  - 0s - loss: 0.2421 - acc: 0.9230 - val_loss: 0.3745 - val_acc: 0.8000
#
# Epoch 00140: val_loss did not improve from 0.37277
# Epoch 141/300
#  - 0s - loss: 0.2359 - acc: 0.9280 - val_loss: 0.3729 - val_acc: 0.8000
#
# Epoch 00141: val_loss did not improve from 0.37277
# Epoch 142/300
#  - 0s - loss: 0.2317 - acc: 0.9269 - val_loss: 0.3759 - val_acc: 0.8000
#
# Epoch 00142: val_loss did not improve from 0.37277
# Epoch 143/300
#  - 0s - loss: 0.2274 - acc: 0.9307 - val_loss: 0.3710 - val_acc: 0.8000
#
# Epoch 00143: val_loss improved from 0.37277 to 0.37102, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 144/300
#  - 0s - loss: 0.2302 - acc: 0.9324 - val_loss: 0.3711 - val_acc: 0.8000
#
# Epoch 00144: val_loss did not improve from 0.37102
# Epoch 145/300
#  - 0s - loss: 0.2250 - acc: 0.9263 - val_loss: 0.3749 - val_acc: 0.7895
#
# Epoch 00145: val_loss did not improve from 0.37102
# Epoch 146/300
#  - 0s - loss: 0.2289 - acc: 0.9352 - val_loss: 0.3734 - val_acc: 0.8000
#
# Epoch 00146: val_loss did not improve from 0.37102
# Epoch 147/300
#  - 0s - loss: 0.2213 - acc: 0.9291 - val_loss: 0.3718 - val_acc: 0.8000
#
# Epoch 00147: val_loss did not improve from 0.37102
# Epoch 148/300
#  - 0s - loss: 0.2201 - acc: 0.9357 - val_loss: 0.3655 - val_acc: 0.8105
#
# Epoch 00148: val_loss improved from 0.37102 to 0.36555, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 149/300
#  - 0s - loss: 0.2196 - acc: 0.9296 - val_loss: 0.3708 - val_acc: 0.8000
#
# Epoch 00149: val_loss did not improve from 0.36555
# Epoch 150/300
#  - 0s - loss: 0.2208 - acc: 0.9352 - val_loss: 0.3726 - val_acc: 0.8105
#
# Epoch 00150: val_loss did not improve from 0.36555
# Epoch 151/300
#  - 0s - loss: 0.2132 - acc: 0.9357 - val_loss: 0.3646 - val_acc: 0.8105
#
# Epoch 00151: val_loss improved from 0.36555 to 0.36460, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 152/300
#  - 0s - loss: 0.2150 - acc: 0.9363 - val_loss: 0.3684 - val_acc: 0.8105
#
# Epoch 00152: val_loss did not improve from 0.36460
# Epoch 153/300
#  - 0s - loss: 0.2114 - acc: 0.9368 - val_loss: 0.3647 - val_acc: 0.8105
#
# Epoch 00153: val_loss did not improve from 0.36460
# Epoch 154/300
#  - 0s - loss: 0.2102 - acc: 0.9357 - val_loss: 0.3612 - val_acc: 0.8105
#
# Epoch 00154: val_loss improved from 0.36460 to 0.36120, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 155/300
#  - 0s - loss: 0.2092 - acc: 0.9380 - val_loss: 0.3650 - val_acc: 0.8105
#
# Epoch 00155: val_loss did not improve from 0.36120
# Epoch 156/300
#  - 0s - loss: 0.2054 - acc: 0.9368 - val_loss: 0.3780 - val_acc: 0.8000
#
# Epoch 00156: val_loss did not improve from 0.36120
# Epoch 157/300
#  - 0s - loss: 0.2059 - acc: 0.9391 - val_loss: 0.3693 - val_acc: 0.8105
#
# Epoch 00157: val_loss did not improve from 0.36120
# Epoch 158/300
#  - 0s - loss: 0.2029 - acc: 0.9418 - val_loss: 0.3633 - val_acc: 0.8105
#
# Epoch 00158: val_loss did not improve from 0.36120
# Epoch 159/300
#  - 0s - loss: 0.1980 - acc: 0.9463 - val_loss: 0.3668 - val_acc: 0.8211
#
# Epoch 00159: val_loss did not improve from 0.36120
# Epoch 160/300
#  - 0s - loss: 0.1976 - acc: 0.9418 - val_loss: 0.3601 - val_acc: 0.8105
#
# Epoch 00160: val_loss improved from 0.36120 to 0.36007, saving model to ./gdrive/My Drive/NLP_Movie/NN_model2.h5
# Epoch 161/300
#  - 0s - loss: 0.1976 - acc: 0.9418 - val_loss: 0.3605 - val_acc: 0.8105
#
# Epoch 00161: val_loss did not improve from 0.36007
# Epoch 162/300
#  - 0s - loss: 0.1961 - acc: 0.9429 - val_loss: 0.3668 - val_acc: 0.8211
#
# Epoch 00162: val_loss did not improve from 0.36007
# Epoch 163/300
#  - 0s - loss: 0.1922 - acc: 0.9418 - val_loss: 0.3646 - val_acc: 0.8211
#
# Epoch 00163: val_loss did not improve from 0.36007
# Epoch 164/300
#  - 0s - loss: 0.1918 - acc: 0.9463 - val_loss: 0.3709 - val_acc: 0.8211
#
# Epoch 00164: val_loss did not improve from 0.36007
# Epoch 165/300
#  - 0s - loss: 0.1926 - acc: 0.9440 - val_loss: 0.3646 - val_acc: 0.8211
#
# Epoch 00165: val_loss did not improve from 0.36007
# Epoch 166/300
#  - 0s - loss: 0.1876 - acc: 0.9479 - val_loss: 0.3708 - val_acc: 0.8211
#
# Epoch 00166: val_loss did not improve from 0.36007
# Epoch 167/300
#  - 0s - loss: 0.1871 - acc: 0.9490 - val_loss: 0.3664 - val_acc: 0.8211
#
# Epoch 00167: val_loss did not improve from 0.36007
# Epoch 168/300
#  - 0s - loss: 0.1867 - acc: 0.9507 - val_loss: 0.3693 - val_acc: 0.8211
#
# Epoch 00168: val_loss did not improve from 0.36007
# Epoch 169/300
#  - 0s - loss: 0.1813 - acc: 0.9490 - val_loss: 0.3703 - val_acc: 0.8211
#
# Epoch 00169: val_loss did not improve from 0.36007
# Epoch 170/300
#  - 0s - loss: 0.1842 - acc: 0.9446 - val_loss: 0.3702 - val_acc: 0.8211
#
# Epoch 00170: val_loss did not improve from 0.36007
# Epoch 00170: early stopping

# %%
#to load best saved model
model = load_model(MAINDIR +'NN_model.h5')

# %%
#predict train
y_pred_train = np.argmax(model.predict(X_train_vec),axis=1)

# %%
#accuracy train
acc_train = sum(y_train == y_pred_train)/len(y_train)
acc_train
# Out:
# 0.9468421052631579

# %%
#predict test
y_pred_test = np.argmax(model.predict(X_test_vec),axis=1)

# %%
#accuracy test
acc_test = sum(y_test == y_pred_test)/len(y_test)
acc_test
# Out:
# 0.81

# %% [markdown]
# The Neural Networks had the highest accuray, for this reason this model is chosen
