# %% [markdown]
# ## BLOQUE 1 CONOCIMIENTOS GENERALES DE PYTHON

# %% [markdown]
# Pregunta 1.1: crea una funcion a la cual le pases por parametros el
# numero de filas y el numero de columnas y te la rellene con numeros aleatorios del 1 al 100 con 2 decimales
# Crea una matriz de 10 filas y 7 columnas. (No utilices NUMPY ni PANDAS en este apartado, en los demás puedes usarlo)

# %%
import random

# %%
 def table(rows=10, columns= 7):  
    numb = []
    for i in range(rows):
        numb.append([round(random.random()*100,2) for _ in range(columns)])
    return numb

# %%
table()
# Out:
# [[88.7, 23.94, 61.99, 28.5, 26.49, 22.13, 70.15],
#  [39.24, 16.97, 53.9, 3.69, 72.82, 83.03, 61.07],
#  [76.98, 8.38, 94.5, 23.94, 84.96, 53.14, 38.12],
#  [75.3, 26.49, 3.44, 83.14, 55.63, 79.78, 53.62],
#  [62.98, 67.68, 3.18, 8.31, 39.86, 60.99, 77.65],
#  [66.89, 10.21, 9.45, 94.98, 97.26, 24.39, 17.38],
#  [47.23, 92.96, 11.39, 80.55, 28.24, 19.47, 50.37],
#  [83.52, 69.9, 29.04, 55.73, 95.67, 96.84, 75.95],
#  [90.02, 19.41, 87.63, 76.44, 98.35, 73.09, 43.87],
#  [89.15, 68.1, 53.62, 32.43, 82.87, 47.3, 50.16]]

# %% [markdown]
# Pregunta 1.2: A partir de la matriz anterior crea un dataframe de PANDAS, poniendo como nombre de columnas los días de la semana
# Si no pudiste crear la matriz del apartado anterior, puedes crear una a partir de NUMPY

# %%
data = table()
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data,columns=['Lunes','Marte','Miercoles','Jueves','Viernes','Sabado','Domingo'])
df
# Out:
#    Lunes  Marte  Miercoles  Jueves  Viernes  Sabado  Domingo
# 0  14.92  86.33      72.26   68.01     6.69   43.76    51.67
# 1  20.09  97.14      65.23   41.07     6.22   50.07    75.49
# 2  78.90  20.57      26.31   68.00    12.25   75.31    72.61
# 3  78.66   7.25       8.36   81.68    88.72   33.73    81.56
# 4  76.74  68.51      48.89    1.80    21.98   75.17    93.43
# 5  95.39  70.51       0.81   62.64    17.79   69.60    23.52
# 6  14.52   3.82      33.40   15.14    20.61   61.60    22.48
# 7  91.16  54.49       5.44   14.27    34.34   11.40     7.51
# 8  70.10  56.30      55.28    2.87    93.29   56.37    74.02
# 9  21.57  29.92      74.93   54.62    91.25   61.51    11.36

# %% [markdown]
# pregunta 1.3: Como crearías una estructura de datos si el tipo de dato no fuera uniforme (mismo tipo de dato)?
# Crea una estructura cuyo primer elemento sea un vector de NUMPY de 10 números aleatorios entre 1 y 100
# Y el segundo elemento un vector con esos mismos valores pero como caracteres.

# %%
a = np.random.randint(1,100,10)
b = [chr(i) for i in a]
print(b)
# Out:
# ['=', ':', 'Q', ' ', '2', '\x06', '>', 'Y', 'M', '\x02']

# %%
pd.DataFrame(list(zip(a,b)), columns=['num','chr'])
# Out:
#    num chr
# 0   61   =
# 1   58   :
# 2   81   Q
# 3   32
# 4   50   2
# 5    6
# 6   62   >
# 7   89   Y
# 8   77   M
# 9    2

# %% [markdown]
# Pregunta 1.4: normaliza todos los elementos de la primera matriz. Esto es, por
# cada elemento resta la media y divide por la desviacion tipica del conjunto.

# %%
datany = np.array(data)

# %%
data_norm = (datany - datany.mean())/datany.std()
data_norm
# Out:
# array([[-1.0719692 ,  1.30027656,  0.83287007,  0.69168474, -1.34537045,
#         -0.11390216,  0.14886866],
#        [-0.9002214 ,  1.65938561,  0.59933292, -0.20326417, -1.36098388,
#          0.09571654,  0.94017092],
#        [ 1.05345138, -0.88427576, -0.69359252,  0.69135253, -1.16066681,
#          0.9341913 ,  0.84449709],
#        [ 1.04547857, -1.3267672 , -1.28989292,  1.1458032 ,  1.37967255,
#         -0.44709954,  1.14181679],
#        [ 0.98169602,  0.70829477,  0.05651684, -1.50781663, -0.83743545,
#          0.92954049,  1.53613912],
#        [ 1.60125047,  0.77473493, -1.54070451,  0.51329292, -0.97662758,
#          0.74450466, -0.78627653],
#        [-1.08525724, -1.44071207, -0.45806216, -1.06466079, -0.88294696,
#          0.47874404, -0.82082542],
#        [ 1.46072954,  0.24254928, -1.38689554, -1.09356226, -0.42683529,
#         -1.18890388, -1.31812998],
#        [ 0.7611147 ,  0.30267762,  0.26879314, -1.47227114,  1.53148831,
#          0.30500303,  0.8913374 ],
#        [-0.85105569, -0.57366804,  0.92156767,  0.24686789,  1.46371935,
#          0.47575423, -1.19023268]])

# %% [markdown]
# Pregunta 1.5: Filtra la matriz normalizada y devuelve los valores entre -1 y 1, sin usar un bucle
# El resultado debe ser un vector con dichos valores ordenados descendentemente

# %%
dn2 = data_norm[(data_norm >= -1) & (data_norm <= 1)].copy()

# %%
dn2[::-1].sort()

# %%
dn2
# Out:
# array([ 0.98169602,  0.94017092,  0.9341913 ,  0.92954049,  0.92156767,
#         0.8913374 ,  0.84449709,  0.83287007,  0.77473493,  0.7611147 ,
#         0.74450466,  0.70829477,  0.69168474,  0.69135253,  0.59933292,
#         0.51329292,  0.47874404,  0.47575423,  0.30500303,  0.30267762,
#         0.26879314,  0.24686789,  0.24254928,  0.14886866,  0.09571654,
#         0.05651684, -0.11390216, -0.20326417, -0.42683529, -0.44709954,
#        -0.45806216, -0.57366804, -0.69359252, -0.78627653, -0.82082542,
#        -0.83743545, -0.85105569, -0.88294696, -0.88427576, -0.9002214 ,
#        -0.97662758])

# %% [markdown]
# ## BLOQUE 2: CREAR HISTOGRAMA Y DIAGRAMA DE BARRAS DE MÁS FRECUENTES.

# %% [markdown]
# 2.1 Crea un vector de números enteros aleatorios entre el 1 y el 10, de tamaño 100
# Crea otro vector de numeros aleatorios entre el 11 y el 20 del mismo tamaño
# y muestra por pantalla la tabla de frecuencia de la unión de los 2 vectores
# para los valores 5,6 y 8 (de la primera) y para los valores 14,16,19 (de la segunda).

# %%
a = np.random.randint(1,10,100)
b = np.random.randint(11,20,100)

# %%
df = pd.DataFrame(list(zip(a,b)),columns=['n1','n2'])

# %%
gp = df[(df['n1'].isin([5,6,8])) & (df['n2'].isin([14,16,19]))].groupby(['n1','n2'])['n1'].count()
gp
# Out:
# n1  n2
# 5   14    2
#     16    4
#     19    3
# 6   16    1
#     19    1
# 8   14    2
#     16    2
# Name: n1, dtype: int64

# %% [markdown]
# 2.2 crea el histograma para dicho vector de frecuencias, con ancho de barra 0.75, título: histograma
# y color de barra azul. Poner un título al eje x para diferenciar que son los números que se van a repetir.

# %%
df2 = df[(df['n1'].isin([5,6,8])) & (df['n2'].isin([14,16,19]))].copy()

# %%
ax = df2.plot(kind='hist', width=0.75, color = 'b')
ax.set_xlabel("Numeros")
ax.set_ylabel("Frecuencia")
# Out:
# Text(0,0.5,'Frecuencia')

# %% [markdown]
# 2.3 crea un diagrama de barras para el vector fusionado
# con los 3 elementos más repetidos, si los hay, sin contar la moda.

# %% [markdown]
# ## BLOQUE 3: CARGA DE FICHEROS Y MODELIZACION.

# %% [markdown]
# Tenemos un fichero llamado data_examen_sanit del cual queremos realizar una modelizacion mediante
# un arbol de decision y una regresión logística.
# La columna objetivo de la tabla se llama "target", y el resto de columnas actuan como input para predecir el Target

# %% [markdown]
# #3.1 Cargue dicho fichero y prepara los datos para la modelización.
# #Con una proporcion 70-30 para los conjuntos train y test.
# #Obtén los estadisticos más importantes para las variables del conjunto de datos

# %%
df = pd.read_csv('data_examen_sanit.txt',sep= '\t')

# %%
df.head()
# Out:
#    target  var1  var2  var3  var4  var5   var6     var7  var8      var9  \
# 0       1     1    61   0.0   0.0   0.0  165.5  0.05625   1.0 -0.198475
# 1       0   164    58   0.0   0.0   0.0    0.0  0.00000   1.0 -0.341181
# 2       1    61    60   0.0   0.0   0.0    0.0  0.00000   1.0 -0.078947
# 3       0   108    49   0.0   0.0   0.0    0.0  0.00000   1.0 -0.924464
# 4       0   157    74   0.0   0.0   0.0    0.0  0.00000   1.0  1.705882
#
#      ...         var13  var14  var15  var16    var17        var18  \
# 0    ...      0.000000      0    0.0      0      0.0     0.000000
# 1    ...      2.333333      4    1.0      0   8400.0  2780.186523
# 2    ...      2.000000      2    3.0      0      0.0     0.000000
# 3    ...      3.666667      4    2.0      0  67320.0     0.000000
# 4    ...      2.000000      3    1.0      0  12600.0  8409.586914
#
#          var19        var20        var21      var22
# 0     0.000000     0.000000     0.000000   0.000000
# 1  5608.359863  3172.283203  3689.523438  11.333333
# 2     0.000000     0.000000     0.000000   5.500000
# 3     0.000000     0.000000  2168.733398   8.500000
# 4  3175.889893  5024.774902     0.000000   0.000000
#
# [5 rows x 23 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(df)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
df2 = pd.DataFrame(scaler.transform(df),columns=list(df.columns))

# %%
df2.head()
# Out:
#    target      var1      var2  var3  var4  var5      var6          var7  var8  \
# 0     1.0  0.011494  0.630769   0.0   0.0   0.0  0.000675  1.056250e-07   1.0
# 1     0.0  0.948276  0.584615   0.0   0.0   0.0  0.000000  1.000000e-07   1.0
# 2     1.0  0.356322  0.615385   0.0   0.0   0.0  0.000000  1.000000e-07   1.0
# 3     0.0  0.626437  0.446154   0.0   0.0   0.0  0.000000  1.000000e-07   1.0
# 4     0.0  0.908046  0.830769   0.0   0.0   0.0  0.000000  1.000000e-07   1.0
#
#            var9    ...        var13     var14     var15         var16  \
# 0  8.015254e-08    ...     0.000000  0.000000  0.000000  1.000000e-07
# 1  6.588195e-08    ...     0.274510  0.363636  0.333333  1.000000e-07
# 2  9.210526e-08    ...     0.235294  0.181818  1.000000  1.000000e-07
# 3  7.553607e-09    ...     0.431373  0.363636  0.666667  1.000000e-07
# 4  2.705882e-07    ...     0.235294  0.272727  0.333333  1.000000e-07
#
#       var17     var18     var19     var20     var21     var22
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.036826  0.019411  0.037421  0.022569  0.058276  0.148796
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.072210
# 3  0.295134  0.000000  0.000000  0.000000  0.034255  0.111597
# 4  0.055239  0.058714  0.021190  0.035749  0.000000  0.000000
#
# [5 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df2.iloc[:,1:]
y = df2['target']

X_train, X_test, y_train, y_test = train_test_split(df2.iloc[:,1:], df2['target'],test_size=0.30, random_state=42)

# %%
df.describe(include = 'all')
# Out:
#              target          var1          var2          var3          var4  \
# count  25827.000000  25827.000000  25827.000000  2.582700e+04  25827.000000
# mean       0.333488     30.225539     44.179812  9.541317e+03      0.150089
# std        0.471468     42.262262     13.317488  6.619398e+04      0.376602
# min        0.000000     -1.000000     20.000000  0.000000e+00      0.000000
# 25%        0.000000      3.000000     33.000000  0.000000e+00      0.000000
# 50%        0.000000     10.000000     43.000000  0.000000e+00      0.000000
# 75%        1.000000     37.000000     55.000000  0.000000e+00      0.000000
# max        1.000000    173.000000     85.000000  2.715397e+06      6.000000
#
#                 var5           var6          var7          var8          var9  \
# count   25827.000000   25827.000000  2.582700e+04  25827.000000  2.582700e+04
# mean      314.090841    2125.847392  2.981376e+05      0.875313  2.791785e+05
# std      5645.001688    3878.574531  1.700765e+06      0.304066  1.647366e+06
# min         0.000000       0.000000 -1.000000e+00      0.000000 -1.000000e+00
# 25%         0.000000       0.000000 -1.892588e-02      1.000000 -6.021422e-01
# 50%         0.000000    1199.500000  0.000000e+00      1.000000  0.000000e+00
# 75%         0.000000    2977.583374  1.426431e-02      1.000000  4.837878e-01
# max    461107.156250  245103.328125  9.999999e+06      1.000000  9.999999e+06
#
#            ...              var13         var14         var15         var16  \
# count      ...       25827.000000  25827.000000  25827.000000  2.582700e+04
# mean       ...           1.201699      2.250126      1.241917  4.142951e+05
# std        ...           1.432546      1.880132      1.081331  1.992853e+06
# min        ...           0.000000      0.000000      0.000000 -1.000000e+00
# 25%        ...           0.000000      1.000000      0.000000  0.000000e+00
# 50%        ...           1.000000      2.000000      1.000000  0.000000e+00
# 75%        ...           2.000000      3.000000      2.000000  0.000000e+00
# max        ...           8.500000     11.000000      3.000000  9.999999e+06
#
#                var17          var18          var19          var20  \
# count   25827.000000   25827.000000   25827.000000   25827.000000
# mean     5064.022473    2326.223824     862.520928     875.276838
# std     11920.527778    7165.683425    4245.409289    3945.945087
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%      5200.000000     856.638336       0.000000       0.000000
# max    228100.000000  143228.750000  149873.453125  140556.906250
#
#               var21         var22
# count  25827.000000  25827.000000
# mean     242.484030      1.262824
# std     1159.344788      3.766725
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      1.000000
# max    63310.980469     76.166664
#
# [8 rows x 23 columns]

# %% [markdown]
# 3.2 Entrene y evalue los modelos. Arbol y reg. logística

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\ebocarru\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.score(X_test, y_test)
# Out:
# 0.7495160665892373

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(X_test, y_test)
# Out:
# 0.6820234869015357

# %% [markdown]
# 3.3 Proponga un método para comparar ambos modelos (ej: Curva ROC)

# %%
from sklearn import model_selection
models = [('RF',RandomForestClassifier()),
          ('LR',LogisticRegression())]
results = []
names = []
seed = 242
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# RF: 0.754282 (0.060195)
# LR: 0.682295 (0.108518)

# %%
import matplotlib.pyplot as plt
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
pd
